# %% [markdown]
# <a href="https://colab.research.google.com/github/Impossiblepretext/Experiment_No.9/blob/main/Experiment_No_9_Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment No.9
#
# Title: Panda
#
# Name: Vibhas Shukla
#
# PRN: 25070123164
#
# Batch: F.Y Entc A1

# %%
# Introduction to panda
# Panda: Panel Data
'''  Used for:
structured data
EDA
Data cleaning'''

# %%
import pandas as pd
s= pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Create a dataframe4
data={"Name":["A","B","C"],"Marks":[85,75,86]}
df=pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     75
# 2    C     86

# %%
df.head(5)
df.tail(5)
# Out:
#   Name  Marks
# 0    A     85
# 1    B     75
# 2    C     86

# %%
#Find the structure of dataframe
df.shape
# Out:
# (3, 2)

# %%
df.size
# Out:
# 6

# %%
# Display column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# check datatypes
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access of Indivisual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
#access specific row
df.iloc[1]
# Out:
# Name      B
# Marks    75
# Name: 1, dtype: object

# %%
#Add a new column
df["Grade"]=["First Class ","Second class","Disctinction"]

# %%
df
# Out:
#   Name  Marks         Grade
# 0    A     85  First Class
# 1    B     75  Second class
# 2    C     86  Disctinction

# %%
#update data in a DataFrame
# Change marks of student A to 88
df.loc[0,"Marks"]=88
df
# Out:
#   Name  Marks         Grade
# 0    A     88  First Class
# 1    B     75  Second class
# 2    C     86  Disctinction

# %%
#delete a coloumn
df.drop("Grade",axis=1,inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     75
# 2    C     86

# %%
#perform basic statistical analysis
df["Marks"].mean()
# Out:
# np.float64(83.0)

# %%
df["Marks"].max()
# Out:
# 88

# %%
df["Marks"].min()
# Out:
# 75

# %%
#apply conditioning
#display students scoring more than 80
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     88
# 2    C     86
